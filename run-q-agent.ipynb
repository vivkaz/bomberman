# %%
# !python3 main.py play --agents q_agent rule_based_agent rule_based_agent rule_based_agent --train 1 --scenario clean --n-rounds 10 --turn-based
# Out:
#   0%|                                                    | 0/10 [00:00<?, ?it/s]events ['MOVED_LEFT', 'CRATE_DISTANCE_REDUCED', 'CRATE_FOUND']
# features [0, 0, 1, -1, -1, 0]
#
# features [0, 1, 1, -1, 0, -1]
#
# [ -16.70496889  -59.27868321 -135.16622993 -130.64558416  -64.43708685
#   -68.79623246]
# old q -16.704968885632745
# new q -13.73894489317636
# events ['INVALID_ACTION', 'CRATE_WITHOUT_DROPPING_BOMB']
# features [0, 1, 1, -1, 0, -1]
#
# features [0, 1, 1, -1, 0, -1]
#
# [-140.10181439 -131.01263489  -52.24536996 -146.67558492  -69.50639156
#     4.3947456 ]
# old q -131.01263489302644
# new q -128.2158442998307
# features [0, 1, 1, -1, 0, -1]
#
# events ['BOMB_DROPPED', 'BOMB_DROPPED_NEXT_TO_CRATE']
# features [0, 1, 1, -1, 0, -1]
#
# features [2, 0, -1, -1, 2, -1]
#
# [-140.10181439 -128.2158443   -52.24536996 -146.67558492  -69.50639156
#     4.3947456 ]
# old q 4.39474559881235
# new q 7.736079908678175
# events ['INVALID_ACTION']
# features [2, 0, -1, -1, 2, -1]
#
# features [2, 0, -1, -1, 2, -1]
#
# [  45.34232077 -130.39264785 -115.76619672 -125.94643831  -77.75673763
#  -123.97923121]
# old q -130.39264785188695
# new q -123.2725741969512
# events ['MOVED_RIGHT', 'CRATE_DISTANCE_INCREASED']
# features [2, 0, -1, -1, 2, -1]
#
# features [2, 0, -1, -1, -1, 1]
#
# [  45.34232077 -123.2725742  -115.76619672 -125.94643831  -77.75673763
#  -123.97923121]
# old q 45.34232077496733
# new q 35.53206945054035
# events ['MOVED_UP', 'BOMB_AVOIDED', 'BOMB_DISTANCE_INCREASED', 'CRATE_DISTANCE_REDUCED']
# features [2, 0, -1, -1, -1, 1]
#
# features [0, 0, -1, 2, -1, 1]
#
# [ -55.28910274 -176.09223775 -119.49879615 -147.53312001  -80.71023217
#  -121.38447736]
# old q -55.28910274366939
# new q -45.71004701117177
# events ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DISTANCE_REDUCED', 'CRATE_FOUND']
# features [0, 0, -1, 2, -1, 1]
#
# features [0, 0, 1, 0, -1, 1]
#
# [-294.40271817  -87.10618455  -29.10114199  -95.74592529   11.66828287
#   -72.65830589]
# old q -29.10114199166946
# new q -24.1503596737808
# events ['MOVED_DOWN', 'CRATE_DISTANCE_INCREASED']
# features [0, 0, 1, 0, -1, 1]
#
# features [0, 0, -1, 0, -1, 1]
#
# [ -9.54813201 -10.         -10.74985224 -11.05135167  -9.75762429
#  -14.080072  ]
# old q -9.548132014203148
# new q -9.236061943129368
# events ['INVALID_ACTION']
# features [0, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, -1, 1]
#
# [  -3.808257   -122.96898046  -54.35578165 -124.39512634  -55.3737987
#   -50.50679529]
# old q -122.96898045800859
# new q -121.01482554255426
# events ['MOVED_DOWN', 'CRATE_DISTANCE_INCREASED']
# features [0, 0, -1, 0, -1, 1]
#
# features [0, 0, 0, -1, -1, 1]
#
# [  -3.808257   -121.01482554  -54.35578165 -124.39512634  -55.3737987
#   -50.50679529]
# old q -54.355781645135494
# new q -49.75207803119545
# events ['INVALID_ACTION']
# features [0, 0, 0, -1, -1, 1]
#
# features [0, 0, 0, -1, -1, 1]
#
# [ -54.45836627   -5.90971723 -138.84708228 -139.60209875  -51.84684812
#   -67.22960896]
# old q -138.84708228303742
# new q -135.4942486053072
# events ['INVALID_ACTION']
# features [0, 0, 0, -1, -1, 1]
#
# features [0, 0, 0, -1, -1, 1]
#
# [ -54.45836627   -5.90971723 -135.49424861 -139.60209875  -51.84684812
#   -67.22960896]
# old q -135.4942486053072
# new q -132.47669829535
# events ['INVALID_ACTION']
# features [0, 0, 0, -1, -1, 1]
#
# features [0, 0, 0, -1, -1, 1]
#
# [ -54.45836627   -5.90971723 -132.4766983  -139.60209875  -51.84684812
#   -67.22960896]
# old q -139.6020987539861
# new q -136.173763429161
# events ['MOVED_LEFT', 'CRATE_DISTANCE_REDUCED']
# features [0, 0, 0, -1, -1, 1]
#
# features [0, 0, 1, -1, 0, -1]
#
# [ -54.45836627   -5.90971723 -132.4766983  -136.17376343  -51.84684812
#   -67.22960896]
# old q -54.458366270787046
# new q -48.65527277405488
# events ['MOVED_LEFT', 'CRATE_DISTANCE_INCREASED']
# features [0, 0, 1, -1, 0, -1]
#
# features [0, 0, 0, -1, 0, 1]
#
# [  -3.808257   -121.01482554  -49.75207803 -124.39512634  -55.3737987
#   -50.50679529]
# old q -3.8082570038503945
# new q -6.0023816247923385
# events ['BOMB_DROPPED']
# features [0, 0, 0, -1, 0, 1]
#
# features [2, 0, 1, -1, 2, 2]
#
# [ -61.56415224  -25.27722579  -63.34889047 -139.43529276  -66.8578527
#   -79.97913156]
# old q -79.97913156480779
# new q -73.44243163499051
# events ['INVALID_ACTION']
# features [2, 0, 1, -1, 2, 2]
#
# features [2, 0, 1, -1, 2, 2]
#
# [ -5.12459141 -56.83230901 -65.74838269 -83.09998212 -74.68451316
#  -74.18174807]
# old q -74.1817480684048
# new q -77.22478648822782
# events ['MOVED_LEFT', 'CRATE_DISTANCE_REDUCED']
# features [2, 0, 1, -1, 2, 2]
#
# features [2, 0, 1, -1, -1, -1]
#
# [ -5.12459141 -56.83230901 -65.74838269 -83.09998212 -74.68451316
#  -77.22478649]
# old q -5.1245914073722245
# new q -8.026036497640462
# events ['MOVED_LEFT', 'BOMB_DISTANCE_INCREASED', 'CRATE_DISTANCE_REDUCED', 'CRATE_FOUND']
# features [2, 0, 1, -1, -1, -1]
#
# features [2, 0, -1, -1, 2, 1]
#
# [ -45.71004701 -176.09223775 -119.49879615 -147.53312001  -80.71023217
#  -121.38447736]
# old q -45.71004701117177
# new q -40.10753293249358
# features [2, 0, -1, -1, 2, 1]
#
# [  -1.87211803 -112.08747667 -130.67926163 -187.22504172 -133.93789744
#  -113.47341514] -133.9378974374827
# [  -1.87211803 -112.08747667 -130.67926163 -187.22504172 -162.54410769
#  -113.47341514] -162.54410769373442
#  10%|████                                    | 1/10 [29:20<4:24:03, 1760.34s/it]events ['INVALID_ACTION']
# features [0, 0, -1, 1, 0, -1]
#
# features [0, 0, -1, 1, 0, -1]
#
# [ -48.65527277   -5.90971723 -132.4766983  -136.17376343  -51.84684812
#   -67.22960896]
# old q -132.47669829535
# new q -129.7609030163885
# events ['MOVED_RIGHT', 'CRATE_DISTANCE_REDUCED', 'CRATE_FOUND']
# features [0, 0, -1, 1, 0, -1]
#
# features [0, 1, 0, -1, 1, -1]
#
# [ -48.65527277   -5.90971723 -129.76090302 -136.17376343  -51.84684812
#   -67.22960896]
# old q -48.65527277405488
# new q -42.193498304868356
# events ['MOVED_LEFT', 'CRATE_DISTANCE_INCREASED', 'CRATE_WITHOUT_DROPPING_BOMB']
# features [0, 1, 0, -1, 1, -1]
#
# features [0, 0, -1, 1, 0, -1]
#
# [-140.10181439 -128.2158443   -52.24536996 -146.67558492  -69.50639156
#     7.73607991]
# old q -52.24536995591681
# new q -48.55270751089864
# events ['WAITED']
# features [0, 0, -1, 1, 0, -1]
#
# features [0, 0, -1, 1, 0, -1]
#
# [ -42.1934983    -5.90971723 -129.76090302 -136.17376343  -51.84684812
#   -67.22960896]
# old q -51.84684812316697
# new q -48.19403786142379
# events ['MOVED_DOWN', 'CRATE_DISTANCE_REDUCED', 'CRATE_FOUND']
# features [0, 0, -1, 1, 0, -1]
#
# features [0, 1, -1, 1, -1, 0]
#
# [ -42.1934983    -5.90971723 -129.76090302 -136.17376343  -48.19403786
#   -67.22960896]
# old q -5.909717228594577
# new q -3.7224983139540835
# events ['MOVED_UP', 'CRATE_DISTANCE_INCREASED', 'CRATE_WITHOUT_DROPPING_BOMB']
# features [0, 1, -1, 1, -1, 0]
#
# features [0, 0, -1, 1, 0, -1]
#
# [-140.10181439 -128.2158443   -48.55270751 -146.67558492  -69.50639156
#     7.73607991]
# old q -48.55270751089864
# new q -45.03246160806465
# events ['WAITED']
# features [0, 0, -1, 1, 0, -1]
#
# features [0, 0, -1, 1, 0, -1]
#
# [ -42.1934983    -3.72249831 -129.76090302 -136.17376343  -48.19403786
#   -67.22960896]
# old q -48.19403786142379
# new q -44.709658923537276
# events ['BOMB_DROPPED']
# features [0, 0, -1, 1, 0, -1]
#
# features [2, 0, -1, 2, 1, -1]
#
# [ -42.1934983    -3.72249831 -129.76090302 -136.17376343  -44.70965892
#   -67.22960896]
# old q -67.22960896310079
# new q -61.6751386892297
# events ['MOVED_DOWN', 'GET_TRAPPED', 'CRATE_DISTANCE_REDUCED']
# features [2, 0, -1, 2, 1, -1]
#
# features [2, 0, -1, -1, -1, -1]
#
# [  -1.87211803 -112.08747667 -130.67926163 -187.22504172 -162.54410769
#  -113.47341514]
# old q -112.08747667036982
# new q -104.8635757355232
# events ['INVALID_ACTION']
# features [2, 0, -1, -1, -1, -1]
#
# features [2, 0, -1, -1, -1, -1]
#
# [-247.10445468 -325.5443414  -252.0554489  -249.15058463  -46.49829702
#  -304.90193198]
# old q -252.0554489048867
# new q -241.0347507465884
#  10%|████                                    | 1/10 [33:49<5:04:23, 2029.29s/it]

# %%
# !python3 main.py play --agents q_agent q_agent q_agent q_agent --scenario classic --n-rounds 1
# Out:
# nonzero rows: 206
# nonzero rows: 206
# nonzero rows: 206
# nonzero rows: 206
#   0%|                                                     | 0/1 [00:00<?, ?it/s]features [0, 0, 1, 0, -1, -1]
#
# features [0, 0, -1, 1, 0, -1]
#
# features [0, 0, -1, -1, 1, 0]
#
# features [0, 0, 1, -1, -1, 0]
#
# features [0, 1, 1, -1, 0, -1]
#
# features [0, 1, -1, 1, -1, 0]
#
# features [0, 1, 0, -1, 1, -1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [0, 1, 1, -1, 0, 1]
#
# features [2, 0, -1, 1, -1, -1]
#
# features [2, 0, -1, -1, 1, -1]
#
# features [2, 0, -1, -1, -1, 1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [0, 0, -1, 1, -1, 2]
#
# features [0, 1, 2, -1, 1, -1]
#
# features [0, 0, -1, 2, -1, 1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [0, 0, -1, 1, -1, 2]
#
# features [0, 1, 2, -1, 1, -1]
#
# features [0, 0, -1, 2, -1, 1]
#
# features [2, 0, 2, -1, -1, 1]
#
# features [0, 0, -1, 1, -1, -1]
#
# features [0, 1, -1, -1, 1, -1]
#
# features [0, 0, -1, -1, -1, 1]
#
# features [1, 0, -1, 2, -1, 0]
#
# oscilation new features [0, 0, -1, 2, -1, 1]
#
# features [0, 1, 1, 1, -1, 0]
#
# features [0, 1, 0, -1, 1, -1]
#
# features [0, 1, -1, 0, 1, 1]
#
# features [1, 0, -1, -1, -1, 0]
#
# oscilation new features [0, 0, -1, -1, -1, 1]
#
# features [0, 1, 1, 1, -1, 0]
#
# features [0, 1, 0, -1, 1, -1]
#
# features [0, 1, -1, 0, 1, 1]
#
# features [0, 1, 1, 0, -1, 1]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [0, 1, 1, 0, -1, 1]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [2, 0, -1, 1, -1, -1]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [2, 0, 1, 2, -1, -1]
#
# features [1, 0, -1, 0, -1, 2]
#
# oscilation new features [0, 0, -1, 1, -1, 2]
#
# features [2, 0, -1, -1, 1, 2]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [0, 0, 1, -1, 2, -1]
#
# features [1, 0, -1, 0, -1, 2]
#
# oscilation new features [0, 0, -1, 1, -1, 2]
#
# features [0, 0, 2, -1, 1, -1]
#
# features [2, 0, 1, -1, -1, 2]
#
# features [3, 0, 1, -1, -1, -1]
#
# features [1, 0, -1, 0, -1, -1]
#
# oscilation new features [0, 0, -1, 1, -1, -1]
#
# features [0, 0, -1, -1, 1, -1]
#
# features [0, 0, 1, -1, 2, -1]
#
# features [0, 1, 0, 1, 0, -1]
#
# features [0, 1, -1, 0, 1, 0]
#
# features [0, 0, 0, -1, 1, 0]
#
# features [0, 0, 1, -1, -1, -1]
#
# features [0, 1, 0, 1, 0, -1]
#
# features [0, 1, -1, 0, 1, 0]
#
# features [0, 0, 0, -1, 1, -1]
#
# features [1, 0, 0, -1, 0, 0]
#
# oscilation new features [0, 0, 0, -1, 0, 1]
#
# features [2, 0, 2, -1, 1, -1]
#
# features [2, 0, -1, 1, -1, 2]
#
# features [0, 1, 0, -1, 1, 1]
#
# features [1, 0, -1, 0, -1, 0]
#
# oscilation new features [0, 0, -1, 0, -1, 1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [0, 0, 1, 0, 0, 0]
#
# features [2, 0, 2, 1, -1, -1]
#
# features [2, 0, -1, -1, 1, 2]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [3, 0, -1, 1, -1, 2]
#
# features [0, 1, 2, -1, 1, -1]
#
# features [2, 0, 2, -1, 2, 1]
#
# features [0, 1, 1, 1, 0, 1]
#
# features [3, 0, 1, 0, -1, 0]
#
# features [0, 1, -1, -1, 1, -1]
#
# features [0, 0, -1, 2, -1, 1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [3, 0, 0, -1, 1, -1]
#
# features [0, 1, 0, -1, 1, -1]
#
# features [0, 0, -1, -1, -1, 1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [3, 0, 0, 1, -1, 0]
#
# features [0, 1, 0, -1, 1, -1]
#
# features [0, 1, 0, 0, 0, 1]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [3, 0, -1, 1, -1, 0]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [0, 1, 0, 0, 0, 1]
#
# features [0, 0, -1, 1, -1, 2]
#
# features [0, 1, 1, 0, -1, 0]
#
# features [2, 0, -1, 1, -1, 0]
#
# features [2, 0, 1, 2, 2, -1]
#
# features [0, 0, -1, 1, -1, -1]
#
# features [2, 0, -1, 2, -1, 1]
#
# features [0, 0, -1, 2, -1, 0]
#
# oscilation new features [0, 0, -1, 2, -1, 1]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [1, 0, 0, -1, 0, 0]
#
# oscilation new features [0, 0, 1, -1, 0, 0]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [0, 0, -1, 2, -1, 0]
#
# oscilation new features [0, 0, -1, 2, -1, 1]
#
# features [2, 0, 1, -1, 0, 2]
#
# features [1, 0, 0, -1, 0, -1]
#
# oscilation new features [0, 0, 1, -1, 0, -1]
#
# features [2, 0, 1, 2, -1, 2]
#
# features [0, 0, -1, -1, -1, 0]
#
# oscilation new features [0, 0, -1, -1, -1, 1]
#
# features [0, 0, 2, -1, 1, -1]
#
# features [0, 0, 1, -1, 0, 0]
#
# features [0, 0, 1, -1, 2, -1]
#
# features [1, 0, -1, 0, 0, 0]
#
# oscilation new features [0, 0, -1, 0, 1, 0]
#
# features [0, 0, -1, -1, 1, -1]
#
# features [0, 1, 1, -1, 0, -1]
#
# features [3, 0, 1, -1, -1, -1]
#
# features [3, 0, 0, -1, 1, -1]
#
# features [0, 0, 0, -1, 1, 0]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [3, 0, 0, 1, 0, 0]
#
# features [0, 1, 0, 1, 0, 0]
#
# features [3, 0, 0, -1, 2, -1]
#
# oscilation new features [0, 0, 1, -1, 2, -1]
#
# features [2, 0, -1, -1, 2, 1]
#
# features [3, 0, -1, 1, -1, 0]
#
# features [2, 0, 1, -1, 2, 2]
#
# features [3, 0, 0, -1, 2, -1]
#
# oscilation new features [0, 0, 1, -1, 2, -1]
#
# features [0, 0, -1, 2, -1, 0]
#
# oscilation new features [0, 0, -1, 2, -1, 1]
#
# features [3, 0, 1, 0, 0, 0]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [3, 0, 0, -1, 2, -1]
#
# oscilation new features [0, 0, 1, -1, 2, -1]
#
# features [0, 0, -1, 2, -1, 0]
#
# oscilation new features [0, 0, -1, 2, -1, 1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [2, 0, -1, 1, 2, 0]
#
# features [3, 0, 0, -1, -1, -1]
#
# oscilation new features [0, 0, 1, -1, -1, -1]
#
# features [0, 0, -1, -1, -1, 1]
#
# features [0, 1, 1, 0, 0, 0]
#
# features [0, 0, -1, 2, -1, 0]
#
# oscilation new features [0, 0, -1, 2, -1, 1]
#
# features [0, 0, 0, -1, 1, 0]
#
# features [3, 0, 1, 0, 0, 0]
#
# features [2, 0, -1, 2, 1, 2]
#
# features [0, 0, -1, -1, -1, 0]
#
# oscilation new features [0, 0, -1, -1, -1, 1]
#
# features [3, 0, 0, -1, 1, -1]
#
# features [3, 0, 1, -1, 0, -1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [0, 0, -1, 0, 1, -1]
#
# features [0, 1, 0, -1, 1, 1]
#
# features [0, 1, 1, 0, 0, 1]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [0, 0, 0, -1, 1, -1]
#
# features [2, 0, 1, -1, 2, -1]
#
# features [2, 0, 2, 2, 1, -1]
#
# features [0, 1, -1, 1, -1, 2]
#
# features [0, 0, 0, 0, 1, -1]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [0, 1, -1, 1, -1, -1]
#
# features [0, 0, 0, -1, 1, -1]
#
# features [2, 0, 2, -1, 2, 1]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [0, 1, -1, 1, -1, 0]
#
# features [0, 1, 0, 1, 1, -1]
#
# features [0, 0, -1, 2, -1, 1]
#
# features [0, 0, -1, 0, -1, 2]
#
# oscilation new features [0, 0, -1, 1, -1, 2]
#
# features [0, 1, -1, 1, -1, 0]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [0, 0, -1, -1, -1, 1]
#
# features [0, 0, -1, 0, -1, -1]
#
# oscilation new features [3, 0, -1, 1, -1, -1]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [3, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, 1]
#
# features [2, 0, 1, -1, 0, 2]
#
# features [2, 0, 2, 1, 2, -1]
#
# features [3, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 1]
#
# features [0, 0, 2, -1, 0, -1]
#
# oscilation new features [0, 0, 2, -1, 1, -1]
#
# features [0, 0, -1, 1, -1, 2]
#
# features [3, 0, 0, 0, 1, 0]
#
# features [3, 0, 1, 0, 0, 0]
#
# features [0, 0, 2, -1, 0, -1]
#
# oscilation new features [0, 0, 2, -1, 1, -1]
#
# features [0, 0, -1, 1, -1, -1]
#
# features [0, 1, 1, -1, 1, -1]
#
# features [0, 1, 1, -1, 0, -1]
#
# features [0, 0, -1, -1, 1, -1]
#
# features [3, 0, 0, 1, 0, 0]
#
# features [2, 0, 1, 0, 2, 0]
#
# features [2, 0, 1, -1, 2, -1]
#
# features [0, 0, 0, 1, -1, 0]
#
# features [3, 0, -1, 1, -1, 0]
#
# features [0, 1, -1, 2, -1, 1]
#
# features [2, 0, 2, 1, -1, 0]
#
# features [0, 0, -1, 1, -1, 0]
#
# features [3, 0, 0, 0, 1, 0]
#
# features [0, 1, -1, 2, -1, 1]
#
# features [3, 0, -1, 2, -1, 1]
#
# features [0, 1, 1, 0, -1, 0]
#
# features [0, 0, 0, -1, 1, -1]
#
# features [0, 1, -1, 2, -1, 1]
#
# features [0, 1, 1, 1, 0, 0]
#
# features [2, 0, -1, 2, -1, 1]
#
# features [0, 1, 0, 1, 1, 0]
#
# features [0, 1, -1, -1, -1, 1]
#
# features [0, 1, 1, 1, 0, 0]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [2, 0, 1, -1, -1, 2]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [0, 1, 1, 1, 0, 0]
#
# features [2, 0, 1, 2, -1, 2]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [0, 1, 1, 1, 0, 0]
#
# features [0, 0, 1, -1, 2, -1]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [2, 0, -1, 1, 2, 2]
# features [0, 0, 1, -1, -1, -1]
#
# features [0, 1, -1, 1, -1, 2]
#
# features [0, 1, -1, 0, -1, 1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [0, 0, 1, 0, 0, 0]
#
# features [0, 1, -1, 1, -1, -1]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [0, 1, -1, 1, -1, 0]
#
# features [2, 0, 1, 2, 0, -1]
#
# features [3, 0, -1, 0, -1, 2]
#
# oscilation new features [3, 0, -1, 1, -1, 2]
#
# features [0, 0, 1, 0, 0, 0]
#
# features [0, 1, -1, 1, -1, 0]
#
# features [0, 1, 2, -1, -1, -1]
#
# features [3, 0, 1, 0, 0, 1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [2, 0, 1, 2, 0, -1]
#
# features [3, 0, -1, 0, -1, 1]
#
# features [0, 1, 0, 0, 0, 1]
#
# features [2, 0, 1, -1, 0, 2]
#
# features [0, 0, -1, -1, 1, -1]
#
# features [3, 0, 1, 0, 0, 1]
#
# features [2, 0, 2, 2, 1, -1]
#
# features [1, 0, 2, -1, 0, -1]
#
# oscilation new features [0, 0, 2, -1, 1, -1]
#
# features [0, 0, 0, 0, 0, 1]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [1, 0, 2, -1, 0, -1]
#
# oscilation new features [0, 0, 2, -1, 1, -1]
#
# features [0, 1, -1, 0, -1, 1]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [1, 0, -1, -1, 0, -1]
#
# oscilation new features [0, 0, -1, -1, 1, -1]
#
# features [2, 0, -1, 1, -1, 2]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [0, 0, -1, 1, -1, 2]
#
# features [0, 0, 0, 0, 2, 0]
#
# oscilation new features [0, 0, 0, 1, 2, 0]
#
# features [2, 0, 1, 2, 0, -1]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [0, 0, -1, 1, -1, -1]
#
# features [0, 0, -1, 1, -1, 0]
#
# features [0, 0, 2, -1, 1, -1]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [0, 1, 1, 1, 0, 0]
#
# features [1, 0, 0, 0, 0, 0]
#
# oscilation new features [0, 0, 0, 0, 0, 1]
#
# features [0, 0, 2, -1, 1, -1]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [0, 1, 1, 1, 0, 0]
#
# features [0, 0, -1, 1, -1, 0]
#
# features [0, 0, -1, -1, 1, -1]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [2, 0, -1, 2, 1, 2]
#
# features [1, 0, 0, 0, 0, 0]
#
# oscilation new features [0, 0, 0, 0, 0, 1]
#
# features [1, 1, 0, 0, 0, 1]
#
# features [2, 0, -1, 1, -1, -1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [0, 0, -1, 1, -1, 0]
#
# features [0, 1, 0, 0, 0, 1]
#
# features [0, 1, 0, 1, 0, 2]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [1, 0, 0, 0, 0, 0]
#
# oscilation new features [0, 0, 0, 0, 0, 1]
#
# features [2, 0, 1, 2, 2, 2]
#
# features [0, 1, 2, -1, 0, -1]
#
# oscilation new features [0, 1, 2, -1, 1, -1]
#
# features [0, 0, -1, 1, -1, 2]
#
# features [0, 0, -1, 1, -1, 0]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [0, 0, 2, -1, 0, -1]
#
# oscilation new features [0, 0, 2, -1, 1, -1]
#
# features [0, 0, -1, 1, -1, -1]
#
# features [0, 0, 0, 1, 0, 0]
#
# features [2, 0, 1, -1, 0, 2]
#
# features [0, 0, 2, -1, 1, -1]
#
# features [0, 1, 1, 1, 1, 0]
#
# features [0, 1, -1, 1, -1, 0]
#
# features [0, 0, 2, -1, 1, -1]
#
# features [0, 1, 2, -1, 1, -1]
#
# features [0, 1, 1, 1, 1, 0]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [0, 0, -1, -1, 1, -1]
#
# features [0, 1, -1, -1, 1, -1]
#
# features [2, 0, -1, 1, -1, 2]
#
# features [2, 0, 1, -1, 0, 2]
#
# features [1, 0, 0, -1, 0, 0]
#
# oscilation new features [1, 0, 0, -1, 0, 1]
#
# features [0, 1, 1, -1, 2, -1]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [0, 1, 2, -1, 1, -1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [0, 1, 1, -1, 2, -1]
#
# features [2, 0, -1, 2, 0, 2]
#
# features [0, 1, 2, -1, 1, -1]
#
# features [0, 0, 0, -1, 0, 1]
#
# features [0, 1, 1, -1, 1, -1]
#
# features [0, 1, 2, -1, 1, -1]
#
# features [0, 1, -1, -1, 1, -1]
#
# features [1, 1, -1, 0, -1, 1]
#
# features [0, 1, 0, 1, 1, 1]
#
# features [2, 0, -1, -1, 1, -1]
#
# features [0, 1, 0, -1, 1, -1]
#
# features [0, 0, 0, -1, 0, 2]
#
# oscilation new features [1, 0, 0, -1, 1, 2]
#
# features [2, 0, 1, 2, 2, 2]
#
# features [3, 0, 2, 0, -1, 1]
#
# features [0, 1, 0, -1, 1, -1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [0, 0, -1, 0, -1, 1]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [0, 1, 0, -1, 1, 1]
#
# features [2, 0, 1, 2, 0, 2]
#
# features [3, 0, 2, 0, -1, 1]
#
# features [2, 0, 2, 1, -1, 0]
#
# features [2, 0, 2, -1, 2, 1]
#
# features [0, 1, 2, -1, 2, -1]
#
# features [0, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 2, -1, 0]
#
# oscilation new features [0, 0, -1, 2, -1, 1]
#
# features [2, 0, -1, -1, -1, -1]
#
# features [2, 0, 1, -1, 0, 2]
#
# features [3, 0, 0, 0, -1, 1]
#
# features [0, 0, -1, 2, -1, 0]
#
# oscilation new features [0, 0, -1, 2, -1, 1]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [0, 1, 2, -1, 0, -1]
#
# oscilation new features [1, 1, 2, -1, 1, -1]
#
# features [3, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, -1, -1, 1]
#
# features [2, 0, 1, 2, -1, 2]
#
# features [0, 1, 1, -1, 1, -1]
#
# features [3, 0, 1, 0, -1, 0]
#
# features [0, 0, 0, 0, 1, 0]
#
# features [0, 0, 1, -1, -1, -1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [0, 0, 0, -1, 1, -1]
#
# features [0, 0, 1, 0, 0, 0]
#
# features [0, 0, 1, 0, 0, 0]
#
# features [0, 1, 0, 0, 0, 1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [2, 0, 1, 2, 2, -1]
#
# features [0, 0, 0, 0, 0, 1]
#
# features [0, 0, 1, 0, 0, 0]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [0, 0, -1, 0, -1, 1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [2, 0, 1, -1, 1, 2]
#
# features [0, 1, 1, 0, 0, 0]
#
# features [0, 1, 1, 0, 0, 0]
#
# features [0, 0, 0, -1, 2, -1]
#
# oscilation new features [0, 0, 1, -1, 2, -1]
#
# features [2, 0, -1, 1, 2, 2]
#
# features [2, 0, -1, 1, 2, 2]
#
# features [0, 0, 1, -1, -1, -1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [0, 0, 0, 2, 0, 0]
#
# oscilation new features [0, 0, 0, 2, 0, 1]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [0, 0, -1, 0, -1, 2]
#
# oscilation new features [0, 0, -1, 1, -1, 2]
#
# features [0, 0, -1, 0, -1, 2]
#
# oscilation new features [0, 0, -1, 1, -1, 2]
#
# features [0, 0, 0, -1, 0, 0]
#
# oscilation new features [0, 0, 1, -1, 0, 0]
#
# features [0, 0, -1, 0, -1, -1]
#
# oscilation new features [0, 0, -1, 1, -1, -1]
#
# features [0, 0, -1, 0, -1, -1]
#
# oscilation new features [1, 0, -1, 1, -1, -1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [0, 0, 0, 0, 0, 1]
#
# features [0, 0, 1, 0, 0, 0]
#
# features [0, 1, 1, 0, 0, 0]
#
# features [0, 0, -1, 0, -1, 1]
#
# features [0, 1, 1, -1, 0, -1]
#
# features [2, 0, -1, 2, 1, 2]
#
# features [3, 0, 1, 0, 1, 0]
#
# features [2, 0, 1, -1, 2, -1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [2, 0, 1, -1, 2, -1]
#
# features [2, 0, 2, 1, -1, 0]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [2, 0, 1, 0, 2, 0]
#
# features [0, 1, -1, 2, -1, 1]
#
# features [0, 1, -1, 1, -1, 2]
#
# features [0, 1, -1, 2, -1, 1]
#
# features [0, 1, -1, 2, -1, 1]
#
# features [0, 1, -1, 1, -1, -1]
#
# features [0, 1, -1, 2, -1, 1]
#
# features [0, 1, -1, -1, -1, 1]
#
# features [0, 1, -1, 1, -1, 0]
#
# features [0, 1, -1, -1, -1, 1]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [0, 1, -1, 1, -1, 0]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [0, 1, 1, 0, 0, 0]
#
# features [2, 0, -1, 1, -1, 2]
#
# features [1, 1, 1, 0, 1, 0]
#
# features [2, 0, 1, 2, 2, 2]
#
# features [2, 0, -1, 2, 1, -1]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [2, 0, 2, -1, 1, -1]
#
# features [0, 1, -1, 1, -1, 2]
#
# features [2, 0, 1, 2, 0, 2]
#
# features [2, 0, 2, -1, 2, 0]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [0, 1, 1, -1, 2, -1]
#
# features [0, 1, -1, 2, -1, 0]
#
# oscilation new features [1, 1, -1, 2, -1, 1]
#
# features [0, 1, -1, 1, -1, 2]
#
# features [0, 1, 1, -1, -1, -1]
#
# features [0, 1, -1, -1, -1, 0]
#
# oscilation new features [1, 1, -1, -1, -1, 1]
#
# features [0, 1, -1, 1, -1, -1]
#
# features [0, 1, 1, -1, 0, -1]
#
# features [0, 1, -1, 1, -1, 0]
#
# features [0, 1, -1, 1, -1, 1]
#
# features [0, 1, 2, -1, 0, -1]
#
# oscilation new features [1, 1, 2, -1, 1, -1]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [2, 0, 1, 2, 0, -1]
#
# features [2, 0, 1, -1, 2, -1]
#
# features [2, 0, 1, -1, 1, 2]
#
# features [0, 1, 2, -1, 0, -1]
#
# oscilation new features [1, 1, 2, -1, 1, -1]
#
# features [2, 0, 2, 1, -1, 2]
#
# features [1, 1, 0, -1, 2, -1]
#
# oscilation new features [0, 1, 1, -1, 2, -1]
#
# features [2, 0, 1, -1, 2, -1]
#
# features [0, 1, -1, 0, -1, 2]
#
# oscilation new features [1, 1, -1, 1, -1, 2]
#
# features [1, 1, 0, -1, 2, -1]
#
# oscilation new features [1, 1, 1, -1, 2, -1]
#
# features [2, 0, 1, 2, -1, -1]
# features [0, 0, -1, 0, -1, -1]
#
# oscilation new features [1, 0, -1, 1, -1, -1]
#
# features [1, 1, 1, -1, -1, -1]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [0, 0, 0, 0, 0, 1]
#
# features [1, 1, 1, -1, 0, -1]
#
# features [2, 0, -1, 1, 2, 1]
#
# features [0, 0, -1, 0, -1, 1]
#
# features [0, 1, 1, 0, 0, 0]
#
# features [0, 1, -1, -1, -1, 1]
#
# features [3, 0, 1, 0, 0, 2]
#
# features [2, 0, 1, 2, 2, 2]
#
# features [0, 1, -1, 1, -1, 2]
#
# features [3, 0, 1, -1, 0, -1]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [0, 1, -1, 1, -1, 2]
#
# features [3, 0, 1, 0, 1, 1]
#
# features [2, 0, 1, 2, 0, 2]
#
# features [1, 1, -1, 1, -1, 2]
#
# features [3, 0, -1, 0, -1, 2]
#
# oscilation new features [3, 0, -1, 1, -1, 2]
#
# features [3, 0, 2, -1, 2, -1]
#
# features [2, 0, -1, 1, -1, 2]
#
# features [3, 0, 0, 0, 0, 1]
#
# features [0, 1, 1, -1, -1, -1]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [3, 0, -1, 0, -1, 2]
#
# oscilation new features [3, 0, -1, 1, -1, 2]
#
# features [3, 0, 2, -1, 0, -1]
#
# oscilation new features [1, 0, 2, -1, 1, -1]
#
# features [2, 0, -1, 2, -1, 2]
#
# features [3, 0, 0, 0, 0, 1]
#
# features [3, 0, 2, -1, 0, -1]
#
# oscilation new features [0, 0, 2, -1, 1, -1]
#
# features [2, 0, 1, 1, 0, 2]
#
# features [0, 1, 1, 0, 0, 1]
#
# features [3, 0, -1, -1, 0, -1]
#
# oscilation new features [0, 0, -1, -1, 1, -1]
#
# features [0, 1, -1, 1, -1, -1]
#
# features [2, 0, 1, 2, 2, -1]
#
# features [0, 0, 1, 1, 0, 0]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [0, 0, -1, 1, -1, 0]
#
# features [2, 0, 1, 2, 0, 2]
#
# features [2, 0, 1, -1, 0, 2]
#
# features [0, 0, 1, 0, 0, 0]
#
# features [0, 0, 1, -1, 2, -1]
#
# features [0, 0, 2, -1, 0, -1]
#
# oscilation new features [1, 0, 2, -1, 1, -1]
#
# features [0, 1, 1, -1, 0, -1]
#
# features [0, 1, 1, -1, 2, -1]
#
# features [0, 0, -1, -1, 0, -1]
#
# oscilation new features [1, 0, -1, -1, 1, -1]
#
# features [2, 0, 2, -1, 1, -1]
#
# features [0, 1, 1, -1, -1, -1]
#
# features [0, 0, 0, -1, 0, 1]
#
# features [2, 0, -1, 1, 2, 0]
#
# features [0, 0, 1, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 1]
#
# features [1, 0, -1, 2, -1, 0]
#
# oscilation new features [0, 0, -1, 2, -1, 1]
#
# features [0, 0, 0, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 1]
#
# features [1, 0, -1, 2, -1, 0]
#
# oscilation new features [0, 0, -1, 2, -1, 1]
#
# features [0, 0, -1, 0, -1, 2]
#
# oscilation new features [0, 0, -1, 1, -1, 2]
#
# features [0, 0, -1, 0, -1, 1]
#
# features [1, 0, -1, -1, -1, 0]
#
# oscilation new features [1, 0, -1, -1, -1, 1]
#
# features [0, 0, -1, 0, -1, -1]
#
# oscilation new features [0, 0, -1, 1, -1, -1]
#
# features [0, 0, 1, 0, 0, 0]
#
# features [0, 0, 0, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [0, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, -1, 1]
#
# features [0, 1, 1, 0, 0, 0]
#
# features [1, 0, 0, 0, 0, 0]
#
# oscilation new features [0, 0, 0, 0, 0, 1]
#
# features [0, 1, 1, 1, 0, 0]
#
# features [2, 0, 1, 2, 2, 2]
#
# features [3, 0, -1, 0, -1, 1]
#
# features [2, 0, -1, 1, 2, 2]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [0, 1, 0, 0, 1, 0]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [2, 0, 1, 2, 0, 2]
#
# features [2, 0, 1, 2, -1, 2]
#
# features [2, 0, 1, 2, 2, 2]
#
# features [0, 0, 1, -1, 2, -1]
#
# features [2, 0, 1, -1, -1, -1]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [0, 0, 1, -1, -1, -1]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [0, 0, 0, 0, 0, 1]
#
# features [0, 0, -1, 0, -1, 2]
#
# oscilation new features [0, 0, -1, 1, -1, 2]
#
# features [0, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 1, -1, -1]
#
# features [0, 0, 0, 0, 0, 1]
#
# features [0, 0, 1, 0, 0, 0]
#
# features [0, 0, -1, 0, -1, 1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [0, 0, 1, 0, 0, 0]
#
# features [1, 0, 0, 0, 0, 0]
#
# oscilation new features [0, 0, 0, 0, 1, 0]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [0, 0, 1, -1, 0, -1]
#
# features [0, 1, -1, 0, 0, 1]
#
# features [0, 0, 0, 1, 0, 0]
#
# features [2, 0, -1, 2, 1, -1]
#
# features [0, 0, -1, 1, -1, 0]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [0, 1, 1, 1, 0, 0]
#
# features [2, 0, 2, 1, 2, 2]
#
# features [2, 0, 2, 1, 2, 2]
#
# features [2, 0, 2, -1, 1, -1]
#
# features [2, 0, -1, -1, 2, -1]
#
# features [0, 1, -1, 0, 0, 1]
#
# features [2, 0, 2, 1, 2, 0]
#
# features [0, 1, 1, 0, 0, 1]
#
# features [0, 1, -1, 1, -1, 2]
#
# features [0, 1, 1, 0, 0, 1]
#
# features [0, 1, -1, 1, -1, -1]
#
# features [2, 0, 1, 2, 2, -1]
#
# features [2, 0, -1, -1, -1, 2]
#
# features [2, 0, -1, 2, -1, -1]
#
# features [2, 0, 1, 2, 0, 2]
#
# features [2, 0, 1, 2, 0, 2]
#
# features [0, 0, 0, -1, 2, -1]
#
# oscilation new features [1, 0, 1, -1, 2, -1]
#
# features [0, 0, 0, -1, 2, -1]
#
# oscilation new features [1, 0, 1, -1, 2, -1]
#
# features [0, 0, 0, -1, 2, -1]
#
# oscilation new features [1, 0, 1, -1, 2, -1]
#
# features [0, 0, 0, -1, -1, -1]
#
# oscilation new features [1, 0, 1, -1, -1, -1]
#
# features [0, 0, 0, -1, -1, -1]
#
# oscilation new features [1, 0, 1, -1, -1, -1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
# features [0, 0, 0, -1, 0, -1]
#
# oscilation new features [1, 0, 0, -1, 1, -1]
#
# features [0, 0, -1, 0, -1, 0]
#
# oscilation new features [1, 0, -1, 0, -1, 1]
#
# features [0, 0, -1, 0, 0, 0]
#
# oscilation new features [1, 0, -1, 0, 0, 1]
#
# features [0, 0, 0, 0, 0, 0]
#
# oscilation new features [1, 0, 0, 0, 1, 0]
#
#   0%|                                                     | 0/1 [00:45<?, ?it/s]

# %%
bomb_area = np.array([[3, 3], [3, 2], [3, 1], [3, 5], [3, 6], [3, 7]])
print(bomb_area)
n = [np.array([2, 5]), np.array([3, 6]),np.array([4, 5]),np.array([3, 4])]
print(np.where([n_.tolist() in bomb_area.tolist() for n_ in n])[0])
# Out:
# [[3 3]
#  [3 2]
#  [3 1]
#  [3 5]
#  [3 6]
#  [3 7]]
# [1]

# %%
#--my-agents --save-replay --turn-based --save-stats

# %%
# !python main.py replay "replays/Round 07 (2022-03-23 12-52-13).pt" --turn-based

# %%
reward = np.load("agent_code/q_agent/rewards.npy")
plt.plot(reward,'.')
plt.xlabel("rounds")
plt.ylabel("reward")
#plt.ylim(-100,100)

# %%
model_trained = np.load("agent_code/q_agent/my-saved-model.npy")

# %%
import itertools
import numpy as np

v = [0,1, -1, 2,  -1, 1]
v1 = [0,1, 2,  -1, 1, -1]
v2 = [0,1, -1, 1, -1, 2]
v3 = [0,1, 1, -1,  2, -1]

NEIGHBOURING_FIELDS = [-1,0,1,2] # the possible values for neighbouring fields
GAME_MODE = [0,1,2,3] # the possible values for game mode
CURRENT_FIELD = [0,1,2] # the possible values for current filed
dic = {}

def get_arrangements(array):
    return [ np.roll(array, -i) for i in range(0,4) ]

# get all possible combinations
def get_variations(array, r=4):
    return [ item for item in list(itertools.product(array, repeat=r)) ]

# compute state to index for the Q-table
def build_state_to_index(arr1 = NEIGHBOURING_FIELDS, arr2 = GAME_MODE, arr3 = CURRENT_FIELD):
    i = 0
    perm = get_variations(arr1)
    comb = np.array(np.meshgrid(arr2, arr3)).T.reshape(-1,2) # combinations of arr2 and arr3
    step = len(comb)
    for p in perm:
        already_there = []
        arrangements = get_arrangements(p)
        for a in arrangements:
            if tuple(a) in dic.keys():
                already_there.append(True)
            else:
                already_there.append(False)
        if sum(already_there) == 0: # p not in dictionary
            value = [v for v in range(i, i+step)] # value indices for p
            i += step # update i
            dic.update({tuple(p) : value}) # add in dictionary

# give corresponding index and rotation from keys
def get_state_index(state):
    arrangements = get_arrangements(state[-4:]) # rotations of neighbouring fields
    mode_and_field = state[:2]
    value_index = 0
    comb = np.array(np.meshgrid(GAME_MODE, CURRENT_FIELD)).T.reshape(-1,2)
    for i, c in enumerate(comb):
        if (c == mode_and_field).all():
            value_index = i
            break
    for j, a in enumerate(arrangements):
        if tuple(a) in dic.keys():
            print(tuple(a), value_index)
            return dic[tuple(a)][value_index], j
    assert True == 0, state
            
build_state_to_index()
#print(get_arrangements(v[-4:]))
print(get_state_index(v))
print(get_state_index(v1))
print(get_state_index(v2))
print(get_state_index(v3))
# Out:
# (-1, 1, -1, 2) 1
# (313, 2)
# (-1, 1, -1, 2) 1
# (313, 1)
# (-1, 1, -1, 2) 1
# (313, 0)
# (-1, 1, -1, 2) 1
# (313, 3)

# %%
import numpy as np
import random

# %%
def dist(pos, objects):
    return np.sqrt( np.power(np.subtract(objects, pos).transpose()[0], 2) + np.power(np.subtract(objects, pos).transpose()[1], 2) )

p = (1,1)
k = [[0,2], [1,2], [1,3], [2,1], [2,1], [1,1]]

distances = np.array(dist(p,k))
print(distances)
print(np.where(distances == min(distances)))

print(dist((4,1), (7,3)))
# Out:
# [1.41421356 1.         2.         1.         1.         0.        ]
# (array([5]),)
# 3.605551275463989

# %%
pos = (0,0)
def get_neighbours(pos):
    sub = [(0,-1), (-1,0), (-2,0), (0,1)] # left, down, right, up

    neighbours = []
    for i in sub:
        neighbour = np.subtract(pos, i)
        if (0 <= neighbour[0] < 17) and (0 <= neighbour[1] < 17): # check if in game borders
            neighbours.append(neighbour)
    return neighbours

neigh = get_neighbours((1,1))
print(neigh)
neigh.append(np.array(pos))
print(neigh)

a = neigh[0]
print(a)
b = (a[0], a[1])
b = np.array(b)
neigh.append(b)
print(neigh)
# Out:
# [array([1, 2]), array([2, 1]), array([3, 1]), array([1, 0])]
# [array([1, 2]), array([2, 1]), array([3, 1]), array([1, 0]), array([0, 0])]
# [1 2]
# [array([1, 2]), array([2, 1]), array([3, 1]), array([1, 0]), array([0, 0]), array([1, 2])]

# %%
pos = np.array((1,5))
area = [[1, 3], [1, 4], [1, 5], [1, 2]]
i = -1
for a in area:
    print(a, pos)
    i += 1
    if ((a == pos).all()):
        print(a, pos)
        break
print(i)
# Out:
# [1, 3] [1 5]
# [1, 4] [1 5]
# [1, 5] [1 5]
# [1, 5] [1 5]
# 2

# %%
pos = (1,2)
pos1 = (1,2)
a = [1,2]
b = ((1,3), (1,2), (2,2))
c = any([(pos==b_) for b_ in b])

print(c)
print(pos!=b[2])
print(pos!=pos1)
# Out:
# True
# True
# False

# %%
mask = [[0]]
n = [[0,1],[1,2],[2,1],[1,0]]

# %%
n.append([pos[0], pos[1]])
print(n)
# Out:
# [[0, 1], [1, 2], [2, 1], [1, 0], [1, 2]]

# %%
a = np.array([5,6,3,2,1,1])
print(min(a))
i = np.where(a==min(a))
print(a[i])
print(1 in a[i])
# Out:
# 1
# [1 1]
# True

# %%
A = np.array([[1, 4], [2, 5], [3, 6]])
B = np.array([[1, 4], [3, 6], [7, 8]])
aset = set([tuple(x) for x in A])
bset = set([tuple(x) for x in B])
intersection = np.array([x for x in aset & bset])
print(intersection)
# Out:
# [[1 4]
#  [3 6]]

# %%
list1 = [(14, 3),(23, 41),(33, 62),(1, 3),(3, 3)]
list2 = [(14, 3),(23, 41),(34, 62),(2, 3),(5, 5)]
list3 = [item for item in list1 if item in list2]
print(list3)
# Out:
# [(14, 3), (23, 41)]

# %%
a = np.array([1, 3, 1, 7])
c = np.array([[0,1],[1,0],[0,0],[1,1]])
b = np.where(a!=1)
print(c)
d = [[0,1], [1,0], [0,0]]

k = np.where([d_ not in c for d_ in d])[0]
print(np.empty(k))
# Out:
# [[0 1]
#  [1 0]
#  [0 0]
#  [1 1]]
# 1.8483715e-316

# %%
a = (1,1)
b = (1,1)
print(a!=b)

print(5 in [5])
# Out:
# False
# True

# %%
a = 1
arr = [7,8,9,5]
print(a in arr)
# Out:
# False

# %%
from datetime import datetime

now = datetime.now() # current date and time

year = now.strftime("%Y")
print("year:", year)

month = now.strftime("%m")
print("month:", month)

day = now.strftime("%d")
print("day:", day)

time = now.strftime("%H:%M:%S")
print("time:", time)

date_time = now.strftime("%H_%M_%S")
print("date and time:",date_time)
# Out:
# year: 2022
# month: 03
# day: 23
# time: 18:59:01
# date and time: 18_59_01

# %%
import time
start = time.time()

time.sleep(5)
end  = time.time()
print(end-start)
